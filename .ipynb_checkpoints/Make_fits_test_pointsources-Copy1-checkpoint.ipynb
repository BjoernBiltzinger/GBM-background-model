# %%
#!/usr/bin python2.7

from astropy.io       import fits
from astropy.table    import Table
from astropy.time     import Time
from datetime         import date
from datetime         import datetime
import ephem
import fileinput
import getpass
import math
import matplotlib.pyplot                   as plt
import matplotlib                          as mpl
import numpy                               as np
from numpy            import linalg        as LA
import os
import pyfits
import scipy.optimize                      as optimization
from scipy            import integrate
from scipy            import interpolate
from scipy.optimize   import curve_fit
import subprocess
from subprocess       import Popen, PIPE
import urllib2
from work_module      import calculate
from work_module      import detector
from work_module      import readfile
from work_module      import writefile
calc = calculate()
det = detector()
rf = readfile()
wf = writefile()

# %%
### Bursttime included ###

day = np.array([150914, 140611, 140102, 130925, 121027, 111209, 101225, '091024'])
#day = np.array(['091024', 101225, 111209, 140102, 140611, 150914, 150926]) #ULGRBs
detector = np.array(['n0', 'n1', 'n2', 'n3', 'n4', 'n5', 'n6', 'n7', 'n8', 'n9', 'na', 'nb'])
#echan = np.array([2, 3, 4, 5, 6])
echan = np.array([0, 1, 2, 3, 4, 5, 6, 7])

burst_array = np.array([[9.846049, 9.846160], 4.90648687, 21.29361, 4.19, 7.54139, 7.20222, 18.62917, 8.932908])

#if len(day) == 1:
#    for j in range(0, len(detector)):
#        for k in range(0,len(echan)):
#            calc.curve_fit_plots(day, detector[j], echan[k])
#else:
for i in range(0, len(day)):
    print day[i]
    for j in range(0, len(detector)):
        print detector[j]
        for k in range(0, len(echan)):
            print echan[k]
            calc.curve_fit_plots(day[i], detector[j], echan[k], plot = 'yes!', burst_time = burst_array[i])
# Out:
# 100803
# n8
# 3
# Making New Directory
# Downloading: glg_ctime_n8_100803_v00.pha Bytes: 11154240
#  Making New Directory
# nb
# 3
# Downloading: glg_ctime_nb_100803_v00.pha Bytes: 11154240
#  Error - curve_fit failed for the value 14.
# 100804
# n8
# 3
# Making New Directory
# Downloading: glg_ctime_n8_100804_v00.pha Bytes: 11856960
#  Making New Directory
# nb
# 3
# Downloading: glg_ctime_nb_100804_v00.pha Bytes: 11856960
#  100805
# n8
# 3
# Making New Directory
# Downloading: glg_ctime_n8_100805_v00.pha Bytes: 11782080
#  Downloading: lat_spacecraft_weekly_w114_p202_v001.fits Bytes: 2615040
#  Making New Directory
# nb
# 3
# Downloading: glg_ctime_nb_100805_v00.pha Bytes: 11782080
#  100806
# n8
# 3
# Making New Directory
# Downloading: glg_ctime_n8_100806_v00.pha Bytes: 11151360
#  Making New Directory
# nb
# 3
# Downloading: glg_ctime_nb_100806_v00.pha Bytes: 11151360
#  Error - curve_fit failed for the value 12.
# 100807
# n8
# 3
# Making New Directory
# Downloading: glg_ctime_n8_100807_v00.pha Bytes: 11145600
#  Making New Directory
# Error - curve_fit failed for the value 14.
# nb
# 3
# Downloading: glg_ctime_nb_100807_v00.pha Bytes: 11145600
#  Error - curve_fit failed for the value 1.
# 100808
# n8
# 3
# Making New Directory
# Downloading: glg_ctime_n8_100808_v00.pha Bytes: 11162880
#  Making New Directory
# nb
# 3
# Downloading: glg_ctime_nb_100808_v00.pha Bytes: 11162880
#  100809
# n8
# 3
# Making New Directory
# Downloading: glg_ctime_n8_100809_v00.pha Bytes: 11217600
#  Making New Directory
# nb
# 3
# Downloading: glg_ctime_nb_100809_v00.pha Bytes: 11217600
#  100810
# n8
# 3
# Making New Directory
# Downloading: glg_ctime_n8_100810_v00.pha Bytes: 11427840
#  Making New Directory
# nb
# 3
# Downloading: glg_ctime_nb_100810_v00.pha Bytes: 11427840
#    11427840  [100.00%]
